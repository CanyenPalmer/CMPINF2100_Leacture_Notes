# %% [markdown]
# ## CMPINF 2100 Week 05 | Read Data into Pandas
#
# ### Import Modules:

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## *Important Preliminaries*
#
# 1) Download the four files in the reading module for this week into the same directory as this notebook.
# 2) Make sure that the files were downloaded and saved into the correct location.

# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Example_A.csv',
#  'Example_B.csv',
#  'Example_C.csv',
#  'Excel_Example_Data.xlsx',
#  'filter_pandas_with_strings.ipynb',
#  'week_05_read_data.ipynb']

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Canye\\OneDrive\\Desktop\\University_of_Pitt\\PDMS\\CMPINF_2100\\publish\\cmpinf_2100_project\\week_05'

# %% [markdown]
# ### Reading Excel Files:

# %%
pd.read_excel( 'Excel_Example_Data.xlsx' )
# Out:
#     A   B     C    D   E   F
# 0   a   0  -100  Jan  aa  10
# 1   b   1  -200  Feb  aa  20
# 2   c   2  -300  Mar  aa  10
# 3   d   3  -400  Apr  bb  20
# 4   e   4  -500  May  bb  10
# 5   f   5  -600  Jun  bb  20
# 6   g   6  -700  Jul  cc  10
# 7   h   7  -800  Aug  cc  20
# 8   i   8  -900  Sep  cc  10
# 9   j   9 -1000  Oct  dd  20
# 10  k  10 -1100  Nov  dd  10
# 11  l  11 -1200  Dec  dd  20

# %%
df0 = pd.read_excel( 'Excel_Example_Data.xlsx' )

# %%
# %whos
# Out:
# Variable   Type         Data/Info
# ---------------------------------
# df0        DataFrame        A   B     C    D   E <...> l  11 -1200  Dec  dd  20
# np         module       <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# os         module       <module 'os' from 'C:\\Us<...>\cmpinf2100\\lib\\os.py'>
# pd         module       <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       12 non-null     object
#  1   B       12 non-null     int64
#  2   C       12 non-null     int64
#  3   D       12 non-null     object
#  4   E       12 non-null     object
#  5   F       12 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 704.0+ bytes

# %% [markdown]
# 6 columns 12 rows, 3 are objects/strings, 3 are integers

# %%
df0.shape
# Out:
# (12, 6)

# %%
df0.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F'], dtype='object')

# %%
df0.dtypes
# Out:
# A    object
# B     int64
# C     int64
# D    object
# E    object
# F     int64
# dtype: object

# %%
df0.index
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %% [markdown]
# We can force one of the columns to be the `.index` attribute when the data are read.

# %%
df0_b = pd.read_excel ( 'Excel_Example_Data.xlsx', index_col = 0)

# %%
df0_b
# Out:
#     B     C    D   E   F
# A
# a   0  -100  Jan  aa  10
# b   1  -200  Feb  aa  20
# c   2  -300  Mar  aa  10
# d   3  -400  Apr  bb  20
# e   4  -500  May  bb  10
# f   5  -600  Jun  bb  20
# g   6  -700  Jul  cc  10
# h   7  -800  Aug  cc  20
# i   8  -900  Sep  cc  10
# j   9 -1000  Oct  dd  20
# k  10 -1100  Nov  dd  10
# l  11 -1200  Dec  dd  20

# %%
df0_b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, a to l
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   B       12 non-null     int64
#  1   C       12 non-null     int64
#  2   D       12 non-null     object
#  3   E       12 non-null     object
#  4   F       12 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 576.0+ bytes

# %%
df0_b.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k', 'l'], dtype='object', name='A')

# %%
df0_b.loc['a']
# Out:
# B       0
# C    -100
# D     Jan
# E      aa
# F      10
# Name: a, dtype: object

# %%
df0_b.loc['c']
# Out:
# B       2
# C    -300
# D     Mar
# E      aa
# F      10
# Name: c, dtype: object

# %%
df0_b.shape
# Out:
# (12, 5)

# %% [markdown]
# We do not just need the zeroth column to be the attribute, it can be any column!

# %%
df0_c = pd.read_excel( 'Excel_Example_Data.xlsx', index_col=4 )

# %%
df0_c
# Out:
#     A   B     C    D   F
# E
# aa  a   0  -100  Jan  10
# aa  b   1  -200  Feb  20
# aa  c   2  -300  Mar  10
# bb  d   3  -400  Apr  20
# bb  e   4  -500  May  10
# bb  f   5  -600  Jun  20
# cc  g   6  -700  Jul  10
# cc  h   7  -800  Aug  20
# cc  i   8  -900  Sep  10
# dd  j   9 -1000  Oct  20
# dd  k  10 -1100  Nov  10
# dd  l  11 -1200  Dec  20

# %%
df0_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, aa to dd
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       12 non-null     object
#  1   B       12 non-null     int64
#  2   C       12 non-null     int64
#  3   D       12 non-null     object
#  4   F       12 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 576.0+ bytes

# %%
df0_c.loc[ 'aa' ]
# Out:
#     A  B    C    D   F
# E
# aa  a  0 -100  Jan  10
# aa  b  1 -200  Feb  20
# aa  c  2 -300  Mar  10

# %% [markdown]
# By default, NONE of the colummns are treated as the `.index`.

# %%
df0_d = pd.read_excel( 'Excel_Example_Data.xlsx', index_col=None )

# %%
df0_d
# Out:
#     A   B     C    D   E   F
# 0   a   0  -100  Jan  aa  10
# 1   b   1  -200  Feb  aa  20
# 2   c   2  -300  Mar  aa  10
# 3   d   3  -400  Apr  bb  20
# 4   e   4  -500  May  bb  10
# 5   f   5  -600  Jun  bb  20
# 6   g   6  -700  Jul  cc  10
# 7   h   7  -800  Aug  cc  20
# 8   i   8  -900  Sep  cc  10
# 9   j   9 -1000  Oct  dd  20
# 10  k  10 -1100  Nov  dd  10
# 11  l  11 -1200  Dec  dd  20

# %%
df0_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       12 non-null     object
#  1   B       12 non-null     int64
#  2   C       12 non-null     int64
#  3   D       12 non-null     object
#  4   E       12 non-null     object
#  5   F       12 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 704.0+ bytes

# %%
df0_d.index
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %% [markdown]
# ### Headers or Column Names:
#
# By default, the `pd.read_` family of functions ASSUMES THE TOP ROW is the HEADER ROW!
#
# The top row therefore does NOT contain VALUES! Instead, it is assumed the TOP ROW or HEADER ROW contains the COLUMN NAMES!

# %%
df0.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F'], dtype='object')

# %%
df0.dtypes
# Out:
# A    object
# B     int64
# C     int64
# D    object
# E    object
# F     int64
# dtype: object

# %%
df0
# Out:
#     A   B     C    D   E   F
# 0   a   0  -100  Jan  aa  10
# 1   b   1  -200  Feb  aa  20
# 2   c   2  -300  Mar  aa  10
# 3   d   3  -400  Apr  bb  20
# 4   e   4  -500  May  bb  10
# 5   f   5  -600  Jun  bb  20
# 6   g   6  -700  Jul  cc  10
# 7   h   7  -800  Aug  cc  20
# 8   i   8  -900  Sep  cc  10
# 9   j   9 -1000  Oct  dd  20
# 10  k  10 -1100  Nov  dd  10
# 11  l  11 -1200  Dec  dd  20

# %% [markdown]
# Let's see what happens if we work with a data set or a sheet within an excel workbook that does not use a header row.
#
# When you know there is no header, then the `header` arguement must be set to `None`.

# %%
df0_no_names = pd.read_excel('Excel_Example_Data.xlsx', sheet_name='no_headers', header=None)

# %%
df0_no_names
# Out:
#     0   1     2    3   4   5
# 0   a   0  -100  Jan  aa  10
# 1   b   1  -200  Feb  aa  20
# 2   c   2  -300  Mar  aa  10
# 3   d   3  -400  Apr  bb  20
# 4   e   4  -500  May  bb  10
# 5   f   5  -600  Jun  bb  20
# 6   g   6  -700  Jul  cc  10
# 7   h   7  -800  Aug  cc  20
# 8   i   8  -900  Sep  cc  10
# 9   j   9 -1000  Oct  dd  20
# 10  k  10 -1100  Nov  dd  10
# 11  l  11 -1200  Dec  dd  20

# %%
df0_no_names.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       12 non-null     object
#  1   1       12 non-null     int64
#  2   2       12 non-null     int64
#  3   3       12 non-null     object
#  4   4       12 non-null     object
#  5   5       12 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 704.0+ bytes

# %%
df0_no_names.columns
# Out:
# Index([0, 1, 2, 3, 4, 5], dtype='int64')

# %% [markdown]
# If there is no header row, we can use the `names` argument to name the columns!

# %%
df0_no_names_2 = pd.read_excel( 'Excel_Example_Data.xlsx',
                               sheet_name='no_headers',
                               header=None,
                               names=df0.columns)

# %%
df0_no_names_2
# Out:
#     A   B     C    D   E   F
# 0   a   0  -100  Jan  aa  10
# 1   b   1  -200  Feb  aa  20
# 2   c   2  -300  Mar  aa  10
# 3   d   3  -400  Apr  bb  20
# 4   e   4  -500  May  bb  10
# 5   f   5  -600  Jun  bb  20
# 6   g   6  -700  Jul  cc  10
# 7   h   7  -800  Aug  cc  20
# 8   i   8  -900  Sep  cc  10
# 9   j   9 -1000  Oct  dd  20
# 10  k  10 -1100  Nov  dd  10
# 11  l  11 -1200  Dec  dd  20

# %%
df0_no_names_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       12 non-null     object
#  1   B       12 non-null     int64
#  2   C       12 non-null     int64
#  3   D       12 non-null     object
#  4   E       12 non-null     object
#  5   F       12 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 704.0+ bytes

# %% [markdown]
# Be very careful if there is a header row and specify that there isn't by mistake!

# %%
df0_mistake = pd.read_excel('Excel_Example_Data.xlsx', header=None)

# %%
df0_mistake.shape
# Out:
# (13, 6)

# %%
df0_mistake.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       13 non-null     object
#  1   1       13 non-null     object
#  2   2       13 non-null     object
#  3   3       13 non-null     object
#  4   4       13 non-null     object
#  5   5       13 non-null     object
# dtypes: object(6)
# memory usage: 752.0+ bytes

# %%
df0_mistake
# Out:
#     0   1      2    3   4   5
# 0   A   B      C    D   E   F
# 1   a   0   -100  Jan  aa  10
# 2   b   1   -200  Feb  aa  20
# 3   c   2   -300  Mar  aa  10
# 4   d   3   -400  Apr  bb  20
# 5   e   4   -500  May  bb  10
# 6   f   5   -600  Jun  bb  20
# 7   g   6   -700  Jul  cc  10
# 8   h   7   -800  Aug  cc  20
# 9   i   8   -900  Sep  cc  10
# 10  j   9  -1000  Oct  dd  20
# 11  k  10  -1100  Nov  dd  10
# 12  l  11  -1200  Dec  dd  20

# %%
df0_mistake.dtypes
# Out:
# 0    object
# 1    object
# 2    object
# 3    object
# 4    object
# 5    object
# dtype: object

# %%
df0.dtypes
# Out:
# A    object
# B     int64
# C     int64
# D    object
# E    object
# F     int64
# dtype: object

# %%
df0_mistake.columns
# Out:
# Index([0, 1, 2, 3, 4, 5], dtype='int64')

# %%
df0.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F'], dtype='object')

# %% [markdown]
# ### Read Other Sheets:
#
# Just specify the `sheet_name` argument appropriately.

# %%
pd.read_excel('Excel_Example_Data.xlsx', sheet_name='ExB')
# Out:
#     E    G
# 0  aa  100
# 1  bb  200
# 2  dd  400

# %%
pd.read_excel('Excel_Example_Data.xlsx', sheet_name='ExC')
# Out:
#     F    H
# 0  10  AAA
# 1  20  BBB
# 2  30  CCC
# 3  40  DDD

# %% [markdown]
# ### Read From CSV
#
# CSV: Comma Seperated Files
#
# CSV files have the extension `.csv`. Unlike excel workbooks, they contain a single spreadsheet rather than multiple.

# %%
pd.read_csv('Example_A.csv')
# Out:
#     A   B     C    D   E   F
# 0   a   0  -100  Jan  aa  10
# 1   b   1  -200  Feb  aa  20
# 2   c   2  -300  Mar  aa  10
# 3   d   3  -400  Apr  bb  20
# 4   e   4  -500  May  bb  10
# 5   f   5  -600  Jun  bb  20
# 6   g   6  -700  Jul  cc  10
# 7   h   7  -800  Aug  cc  20
# 8   i   8  -900  Sep  cc  10
# 9   j   9 -1000  Oct  dd  20
# 10  k  10 -1100  Nov  dd  10
# 11  l  11 -1200  Dec  dd  20

# %% [markdown]
# `pd.read_csv()` has nearly all the same arguments as `pd.read_excel()`!

# %%
pd.read_csv('Example_A.csv', index_col=0)
# Out:
#     B     C    D   E   F
# A
# a   0  -100  Jan  aa  10
# b   1  -200  Feb  aa  20
# c   2  -300  Mar  aa  10
# d   3  -400  Apr  bb  20
# e   4  -500  May  bb  10
# f   5  -600  Jun  bb  20
# g   6  -700  Jul  cc  10
# h   7  -800  Aug  cc  20
# i   8  -900  Sep  cc  10
# j   9 -1000  Oct  dd  20
# k  10 -1100  Nov  dd  10
# l  11 -1200  Dec  dd  20

# %% [markdown]
# A few other important arguments you may need.
#
# We can spefify the max numbers of rows to read!

# %%
pd.read_csv('Example_A.csv', nrows=3)
# Out:
#    A  B    C    D   E   F
# 0  a  0 -100  Jan  aa  10
# 1  b  1 -200  Feb  aa  20
# 2  c  2 -300  Mar  aa  10

# %% [markdown]
# We can also skip rows.

# %%
pd.read_csv('Example_A.csv', skiprows=2)
# Out:
#    b   1  -200  Feb  aa  20
# 0  c   2  -300  Mar  aa  10
# 1  d   3  -400  Apr  bb  20
# 2  e   4  -500  May  bb  10
# 3  f   5  -600  Jun  bb  20
# 4  g   6  -700  Jul  cc  10
# 5  h   7  -800  Aug  cc  20
# 6  i   8  -900  Sep  cc  10
# 7  j   9 -1000  Oct  dd  20
# 8  k  10 -1100  Nov  dd  10
# 9  l  11 -1200  Dec  dd  20

# %% [markdown]
# When you skip rows, be very careful with the Header!

# %%
pd.read_csv('Example_A.csv', skiprows=2, header=None)
# Out:
#     0   1     2    3   4   5
# 0   b   1  -200  Feb  aa  20
# 1   c   2  -300  Mar  aa  10
# 2   d   3  -400  Apr  bb  20
# 3   e   4  -500  May  bb  10
# 4   f   5  -600  Jun  bb  20
# 5   g   6  -700  Jul  cc  10
# 6   h   7  -800  Aug  cc  20
# 7   i   8  -900  Sep  cc  10
# 8   j   9 -1000  Oct  dd  20
# 9   k  10 -1100  Nov  dd  10
# 10  l  11 -1200  Dec  dd  20

# %% [markdown]
# Read in the 3 CSV files and assign them to different objects.

# %%
dfA = pd.read_csv('Example_A.csv')

# %%
dfB = pd.read_csv('Example_B.csv')

# %%
dfC = pd.read_csv('Example_C.csv')

# %%
dfA
# Out:
#     A   B     C    D   E   F
# 0   a   0  -100  Jan  aa  10
# 1   b   1  -200  Feb  aa  20
# 2   c   2  -300  Mar  aa  10
# 3   d   3  -400  Apr  bb  20
# 4   e   4  -500  May  bb  10
# 5   f   5  -600  Jun  bb  20
# 6   g   6  -700  Jul  cc  10
# 7   h   7  -800  Aug  cc  20
# 8   i   8  -900  Sep  cc  10
# 9   j   9 -1000  Oct  dd  20
# 10  k  10 -1100  Nov  dd  10
# 11  l  11 -1200  Dec  dd  20

# %%
dfB
# Out:
#     E    G
# 0  aa  100
# 1  bb  200
# 2  dd  400

# %%
dfC
# Out:
#     F    H
# 0  10  AAA
# 1  20  BBB
# 2  30  CCC
# 3  40  DDD

# %% [markdown]
# ### Reading or Downloading from a Website:
#
# The data might be located at a web address or URL

# %%
gap_url = 'https://raw.githubusercontent.com/chendaniely/pandas_for_everyone/master/data/gapminder.tsv'

# %%
type (gap_url)
# Out:
# str

# %% [markdown]
# To read in the data, we provide the URL web address as a string instead of a file name on our computer!
#
# Because we are reading a tab seperated file (TSV) instead of a CSV, we need to change the `sep` argument.

# %%
gap_df = pd.read_csv(gap_url, sep= '\t')

# %%
gap_df.shape
# Out:
# (1704, 6)

# %%
gap_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %% [markdown]
# ### Read or Load Data from Modules:
#
# We will use data from modules throughout the ADDM program.
#
# We just need to make sure the module is imported!

# %%
import seaborn as sns

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB
